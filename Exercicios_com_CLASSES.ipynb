# %% [markdown]
# <a href="https://colab.research.google.com/github/EddyGiusepe/Exercicios_classes_herenca_Python/blob/main/Exercicios_com_CLASSES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <h2 align='center'>Exercícios de Classes com Python</h2>
#
#
# **Cientista de Dados Jr.:**  Dr.Eddy Giusepe Chirinos Isidro

# %% [markdown]
# Aqui vamos a resolver vários exercícios da [lista da Python Brasil](https://wiki.python.org.br/ListaDeExercicios).
#
#
# A seguir podemos lembrar alguns programas em Python com o Playlist: [DevPro](https://www.youtube.com/watch?v=cW_-2b9TeCM&list=PLA05yVJtRWYQ-8I-kJCW2lCeWVUQNFC67&index=1).

# %% [markdown]
# ## Estrutura de repetição

# %% [markdown]
# A seguir vamos tratar um erro no Python. Também podemos entender o seguinte trecho de código como um código, na qual queremos que o usuário digite um valor válido. Vamos lá:

# %%
while True:
  
  try:
    numero = int(input("Digite um valor de 0 a 10: "))
  except ValueError:
    print("Deve ser fornecido um valor inteiro")
  else:
    if 0<= numero <= 10:
      print(f"Número informado é: {numero}")
      break
    else:
      print("O número deve estar entre 0 e 10")
# Out:
# Digite um valor de 0 a 10: -3
# O número deve estar entre 0 e 10
# Digite um valor de 0 a 10: 12
# O número deve estar entre 0 e 10
# Digite um valor de 0 a 10: ssss
# Deve ser fornecido um valor inteiro
# Digite um valor de 0 a 10: 6
# Número informado é: 6

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 1
#
# A seguir apresentamos uma breve introdução:

# %%
class CirculoPerfeitoteste():
  pass

# %%
# Com a mesma forma podemos criar vários objetos diferentes
circulo_primeiroteste = CirculoPerfeitoteste()

circulo_segundoteste = CirculoPerfeitoteste()

# %%
# Tipo do circulo:

print(type(circulo_primeiroteste))
# Out:
# <class '__main__.CirculoPerfeitoteste'>

# %%
print(type(circulo_segundoteste))
# Out:
# <class '__main__.CirculoPerfeitoteste'>

# %%
# Os objetos são diferentes

print(circulo_primeiroteste is circulo_segundoteste)   # ou print(circulo_primeiro == circulo_segundo)
# Out:
# False

# %% [markdown]
# Agora sim, vamos criar nosso método

# %%
# Vamos criar nosso método dentro da nossa classe

class CirculoPerfeito():
  def __init__(self):
    self.cor = "Azul"
    self.circunferencia = 4
    self.material = "papel"


  #def mostra_cor(self):
    #return id(self)
  def mostra_cor(self):
    return self.cor  

  def trocar_cor(self, cor):
    self.cor = cor

# %%
circulo_primeiro = CirculoPerfeito()
circulo_segundo = CirculoPerfeito()

#circulo_segundo.cor = "Amarelo" 
circulo_segundo.trocar_cor("Amarelo")


print(id(circulo_primeiro), circulo_primeiro.mostra_cor())
print(id(circulo_segundo), circulo_segundo.mostra_cor())


print(circulo_primeiro.cor, circulo_segundo.cor)
# Out:
# 139925797057488 Azul
# 139925797059024 Amarelo
# Azul Amarelo

# %%
# Posso alterar a cor do atributo

circulo_segundo.cor = "Verde"
print(circulo_primeiro.cor, circulo_segundo.cor)
# Out:
# Azul Verde

# %% [markdown]
# ## Exercício 7

# %%
maximo = float(input("Digite um número: "))

for _ in range(4):
  maximo = max(maximo, float(input("Digite um número: ")))
  print(f"Número máximo encontrado até agora é: {maximo}")
# Out:
# Digite um número: 1
# Digite um número: 2
# Número máximo encontrado até agora é: 2.0
# Digite um número: 3
# Número máximo encontrado até agora é: 3.0
# Digite um número: 4
# Número máximo encontrado até agora é: 4.0
# Digite um número: 5
# Número máximo encontrado até agora é: 5.0

# %% [markdown]
# ## Exercício 7

# %% [markdown]
# ## <font color="orange">Recursão em Python</font>

# %% [markdown]
# Características:
#
# * Quando uma função chama ela mesma,
#
# * Repetição de tarefas quando uma estrutura de repetição não é adequada,
#
# * Construção de estruturas de Dados específicas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for _ in range(5):
  print("Recursão")
# Out:
# Recursão
# Recursão
# Recursão
# Recursão
# Recursão

# %%
# Agora usaremos recursão

def recursao(i):
  print("Recursão")
  i += 1
  if i == 5:
    return
  else:
    recursao(i)


# NOTA:
# Ver o arquivo no Pycharm para o "Debugger", para um melhor entendimento

# %%
recursao(0)
# Out:
# Recursão
# Recursão
# Recursão
# Recursão
# Recursão
